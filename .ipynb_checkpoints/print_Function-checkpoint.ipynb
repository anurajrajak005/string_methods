# %% [raw]
# print is Build-Function

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(False)
# Out:
# False

# %%
print(5.6)
# Out:
# 5.6

# %%
print("India","Pakistan","Nepal","Srilanka")
# Out:
# India Pakistan Nepal Srilanka

# %%
print("Anuraj",5,True)
# Out:
# Anuraj 5 True

# %%
print("India","Pakistan","Nepal","Srilanka",sep="-")
# Out:
# India-Pakistan-Nepal-Srilanka

# %%
print("India","Pakistan","Nepal","Srilanka",sep="/")
# Out:
# India/Pakistan/Nepal/Srilanka

# %%
print("India","Pakistan","Nepal","Srilanka",sep="|")
# Out:
# India|Pakistan|Nepal|Srilanka

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello",end=" ")
print("World")
# Out:
# Hello World

# %%
print()+then shift+ tab
