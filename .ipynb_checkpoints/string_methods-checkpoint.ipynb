# %%
A = "hello world"
A.upper()
# Out:
# 'HELLO WORLD'

# %%
"HELLO WORLD"
A.lower()
# Out:
# 'hello world'

# %%
A = "hello world"
A.capitalize()
# Out:
# 'Hello world'

# %%
A = "hello world"
A.title()
# Out:
# 'Hello World'

# %%
A = " hello world "
A.strip()
# Out:
# 'hello world'

# %%
A = " hello world "
A.lstrip()
# Out:
# 'hello world '

# %%
A = " hello world "
A.rstrip()
# Out:
# ' hello world'

# %%
A = "I love Python"
A.replace("love", "like")
# Out:
# 'I like Python'

# %%
A = "a,b,c,d"
A.split(",")
# Out:
# ['a', 'b', 'c', 'd']

# %%
A = "one two three"
A.split()
# Out:
# ['one', 'two', 'three']

# %%
A = "hello world" # starting index
A.find("world")
# Out:
# 6

# %%
A = "hello world"
A.rfind("world") # last index
# Out:
# 6

# %%
A = "mississippi"
A.count("s") # count a world
# Out:
# 4

# %%
A = "mississippi"
A.count("m")
# Out:
# 1

# %%
A = "python123"
A.isalnum() # check a alphabets and number
# Out:
# True

# %%
A = "python"
A.isalpha()  # only check a alphabets number
# Out:
# True

# %%
A = "12345"
A.isdigit() # only for find a numerica value
# Out:
# True
